# %%
import csv
import json

# %%
data={}
with open('file.csv',mode='r') as f:
    reader=csv.reader(f)
    for row in reader:
        key,value=row
        data[key]=value
with open('file.json',mode='w') as ff:
    json.dump(data,ff,indent=4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 6
#       4     for row in reader:
#       5         key,value=row
# ----> 6         data.update(row)
#       7 with open('file.json',mode='w') as ff:
#       8     json.dump(data,ff,indent=4)
#
# ValueError: dictionary update sequence element #0 has length 4; 2 is required
